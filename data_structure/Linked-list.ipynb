# %% [markdown]
# ## 无序链表
# #### 1.定义:
# 1. 无序链表是项的集合，每个项保持了与其他项的相对位置
#
# #### 2.无序链表操作
# * List() 创建一个新的空列表。它不需要参数，并返回一个空列表。
# * add(item) 向列表中添加一个新项。它需要 item 作为参数，并不返回任何内容。假定该 item 不在列表中。
# * remove(item) 从列表中删除该项。它需要 item 作为参数并修改列表。假设项存在于列表中。
# * search(item) 搜索列表中的项目。它需要 item 作为参数，并返回一个布尔值。
# * isEmpty() 检查列表是否为空。它不需要参数，并返回布尔值。
# * size（）返回列表中的项数。它不需要参数，并返回一个整数。
# * append(item) 将一个新项添加到列表的末尾，使其成为集合中的最后一项。它需要 item 作为参数，并不返回任何内容。假定该项不在列表中。
# * index(item) 返回项在列表中的位置。它需要 item 作为参数并返回索引。假定该项在列表中。
# * insert(pos，item) 在位置 pos 处向列表中添加一个新项。它需要 item 作为参数并不返回任何内容。假设该项不在列表中，并且有足够的现有项使其有 pos 的位置。
# * pop() 删除并返回列表中的最后一个项。假设该列表至少有一个项。
# * pop(pos) 删除并返回位置 pos 处的项。它需要 pos 作为参数并返回项。假定该项在列表中
#
# #### 3.python实现

# %% [markdown]
# #### 3.1节点Node
# 1. 作用：构建链表的结构的基础单位
# 2. 组成：
#     * 数据字段，对项的存储
#     * 对一下个节点的引用
#     * 接地引用None
# ![Node](pic/Node.png)
# <center>节点<center>
#
# 3. 链表中最后一个节点对下一个节点的引用为None

# %%
class Node:
    def __init__(self,initdata):
        self.data = initdata
        self.next = None
    
    def getData(self):
        return self.data
    
    def getNext(self):
        return self.next
    
    def setData(self,newdata):
        self.data = newdata
        
    def setNext(self,newnext):
        self.next = newnext

# %% [markdown]
#  **空链表head引用值与接地节点对下一个引用值必须相同，python中用None**

# %%
class UnorderedList() :
    def __init__(self):
        self.head = None

    def isEmpty(self):
        return self.head == None

    def add(self, item):
        temp = Node(item)
        temp.setNext(self.head)
        self.head = temp

    def size(self):
        current = self.head
        count = 0
        '''
        节点遍历法
        while current != None:
            current = current.getNext()
        '''
        while current != None:
            count += 1
            current = current.getNext()
            # 一但遍历到最后一个节点，则getNext（）的值为None
        return count

    def search(self, item):
        current = self.head
        found = False

        while current != None and not found:
            if current.getData() == item:
                found = True
            else:
                current = current.getNext()

        return found

    def remove(self, item):
        current = self.head
        previous = None
        found = False

        while not found:
            if current.getData() == item:
                found = True
            else:
                previous = current
                current = current.getNext()

        if previous == None:
            self.head = current.getNext()
        else:
            previous.setNext(current.getNext())

    def append(self, item):
        temp = Node(item)
        current = self.head

        while current != None:
            if current.getNext() != None:  # 最后一个节点的特征
                current = current.getNext()
            else:
                current.setNext(temp)
                break

        if current == None:  # 链表为空
            temp.setNext(self.head)
            self.head = temp

    def index(self, item):
        current = self.head
        found = False
        index = None
        count = 0

        while not found and current != None:  # 没有找到且链表不为空
            if current.getData() != item:
                current = current.getNext()
                count += 1
            else:
                found = True
                index = count

        return index

    def insert(self, item, pos=0):

        ListSize = self.size()

        if ListSize == 0:
            if pos == 0:
                self.add(item)
            else:
                return 'The List is Empty your pos is illegal'#使用try exception来优化
        else:
            if pos == 0:
                self.add(item)
            elif pos <= ListSize:
                current = self.head
                previous = None
                count = 0
                temp = Node(item)

                while count < pos:
                    previous = current
                    current = current.getNext()
                    count += 1

                previous.setNext(temp)
                temp.setNext(current)
            else:
                return 'the pos out of the List!'#使用try exception来优化

    def pop(self, pos = None):
        if pos == None:
            current = self.head
            previous = None
            if not self.isEmpty():
                if current.getNext() != None:#链表至少有两个节点
                    while current.getNext() != None:
                        previous = current
                        current = current.getNext()

                    previous.setNext(None)
                else:#链表只有一个节点
                    self.head = None
                return current.getData()
            else:
                return current
        else:
            ListSize = self.size()

            if ListSize == 0:
                return 'The List is Empty'
            else:
                if pos < ListSize:
                    current = self.head
                    previous = None
                    count = 0
                    if pos == 0:
                        current.setNext(self.head)
                        return current.getData()
                    else:
                        while count < pos:
                            previous = current
                            current = current.getNext()
                            count += 1
                        previous.setNext(current.getNext())
                        return current.getData()
                else:
                    return 'the pos out of the List!'  # 使用try

# %% [markdown]
# <left><font color=red size=5>** 函数在同一个作用域中函数重名 **</font></left>
#
# **当函数在同一个作用域中重名时，程序执行此方法执行的是空间位置在最后的方法**
#
# ---
#     class A():
#     def ABC(self, a):
#         print(type(str(a)))
#     def ABC(self, a):
#         print(type(int(a)))
#
#     if __name__=="__main__":
#         a = A()
#         a.ABC(10)
#
#     执行结果：<class 'int'>
# ___

# %% [markdown]
# ## 有序列表
# #### 1.定义
# 1. 具有升序或降序性质的链表
#
# #### 2.与无序链表的区别
# 1. add()方法，需要对添加的新项与已有项进行比较后确定插入位置，然后再插入新项
# 2. search()方法，由于列表本身具有序的属性，所以在搜索到比查找项大的链表项后就可以停止搜索。
#
# #### 3.有序列表操作
# 1. 与无序列表一样

# %%
#my code
class OrderList():
    def __init__(self):
        self.head = None

    def isEmpty(self):
        return self.head == None

    def size(self):
        current  = self.head
        count = 0
        while current != None:
            current = current.getNext()
            count += 1

        return count
    
    #my code
    def search(self, item):
        found = False
        current = self.head
        while current != None and not found:
            if current.getData() == item:
                found = True
            elif current.getData() > item:
                break
            else:
                current = current.getNext()
        return found
    
    #teach code 
    def search(self,item):
        current = self.head
        found = False
        stop = False
        while current != None and not found and not stop:
        #current != None解决了空列表的情况，同时满现遍历条件
            if current.getData() == item:
                found = True
            else:
                if current.getData() > item:
                    stop = True
                else:
                    current = current.getNext()
        return found
    
    # my code
    def add(self, item):
        temp = Node(item)
        current = self.head
        previous = None
        insert = False
        if not self.isEmpty():
            if current.getNext() != None:#有至少两个节点

                if item <= current.getData():#新增数据比第一个节点小
                    self.head = temp
                    temp.setNext(current)
                    insert = True

                while current != None and not insert:
                    previous = current
                    current = current.getNext()
                    if item <= current.getData():
                        previous.setNext(temp)
                        temp.setNext(current)
                        insert = True

                if not insert:
                    current.setNext(temp)
            else:#列表中只有一个节点
                if current.getData() < item:
                    current.setNext(temp)
                else:
                    self.head = temp
                    temp.setNext(current)
        else:
            self.head = temp
#teach code
    def add(self,item):
        current = self.head
        previous = None
        stop = False
        
        #确定新增节点的位置
        while current != None and not stop:
            if current.getData() > item:
                stop = True
            else:
                previous = current
                current = current.getNext()
        
        #插入节点
        temp = Node(item)
        if previous == None:
            temp.setNext(self.head)
            self.head = temp
        else:
            temp.setNext(current)
            previous.setNext(temp)

if __name__ == '__main__':
    List = OrderList()
    List.add(2)
    List.add(1)
    List.add(5)
    List.add(3)
    print(List.search(3))
# Out:
# True

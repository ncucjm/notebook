# %% [markdown]
# <img src="pic/pic_2.png" width="500" align="bottom" />
#
# #### requests 中文文档:<br />https://requests.readthedocs.io/zh_CN/latest/

# %%
import requests

if __name__ == '__main__':
    target = 'http://gitbook.cn'
    req = requests.get(url=target)
    print(req.text)

# %%
# coding=utf-8
import requests

if __name__ == '__main__':
    target = 'https://read.qidian.com/chapter/6VV-_gU5iIhhO--gcH8iFg2/kUcpdSn2Vx9Ms5iq0oQwLQ2'
    req = requests.get(url=target)
    print(req.text)
# Out:
# <link data-ignore="true" rel="Bookmark" type="image/x-icon" href="//qidian.gtimg.com/qd/favicon/qd_icon.c443c.ico">
# <link rel="stylesheet" data-ignore="true" href="//qidian.gtimg.com/c/=/qd/css/lbfUI/css/icon.a578d.css,/qd/css/lbfUI/css/Drag.41d31.css,/qd/css/lbfUI/css/Checkbox.ef549.css,/qd/css/reset.ddecf.css,/qd/css/global.d41d8.css,/qd/css/font.1727c.css,/qd/css/module.a841b.css,/qd/css/footer.68e1d.css,/qd/css/read.34898.css,/qd/css/review.64e5b.css,/qd/css/emoji.3b60e.css,/qd/css/layout.5de0f.css,/qd/css/qd_popup.ed72c.css,/qd/css/book_popup.18f47.css,/qd/css/vote_popup.3844d.css" />
# </head>
#     <div class="read-header" id="readHeader" data-l1="40">
#     <div class="wrap-center cf">
#         <div class="left-nav fl">
#             <div class="logo">
#                 <a class="logo-ico" href="javascript:"></a>
#             </div>
#             <ul>
#                 <li class="site" data-l2="1">
# ...

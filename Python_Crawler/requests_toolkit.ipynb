# %% [markdown]
# <img src="pic/pic_2.png" width="500" align="bottom" />
#
# #### requests 中文文档:<br />https://requests.readthedocs.io/zh_CN/latest/

# %%
import requests

if __name__ == '__main__':
    target = 'http://gitbook.cn'
    req = requests.get(url=target)
    print(req.text)

# %%
# coding=utf-8
import requests

if __name__ == '__main__':
    target = 'http://www.biqukan.com/1_1094/5403177.html'
    req = requests.get(url=target)
    print(req.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=gbk" />
# <title>µÚÒ»ÕÂ Ëû½Ð°×Ð¡´¿_Ò»ÄîÓÀºã_ÐÞÕæÐ¡Ëµ_±ÊÈ¤¸ó</title>
# <meta name="keywords" content="Ò»ÄîÓÀºã, µÚÒ»ÕÂ Ëû½Ð°×Ð¡´¿" />
# <meta name="description" content="±ÊÈ¤¸óÌá¹©ÁË¶ú¸ù´´×÷µÄÐÞÕæÐ¡Ëµ¡¶Ò»ÄîÓÀºã¡·¸É¾»ÇåË¬ÎÞ´í×ÖµÄÎÄ×ÖÕÂ½Ú£ºµÚÒ»ÕÂ Ëû½Ð°×Ð¡´¿ÔÚÏßÔÄ¶Á¡£" />
# <meta http-equiv="Cache-Control" content="no-transform" />
# <meta http-equiv="Cache-Control" content="no-siteapp" />
# <meta http-equiv="mobile-agent" content="format=html5; url=https://n.biqukan.com/1/1094/5403177.html" />
# <meta http-equiv="mobile-agent" content="format=xhtml; url=https://n.biqukan.com/1/1094/5403177.html" />
# <link href="/css/style.css" rel="stylesheet" type="text/css" />
# <script src="https://apps.bdimg.com/libs/jquery/1.8.3/jquery.min.js"></script>
# <script src="/xxgg/common.js"></script>
# <script src="/xxgg/read.js"></script>
# <script type="text/javascript">
# var preview_page = "/1_1094/5386268.html";
# var next_page = "/1_1094/5428081.html";
# var index_page = "/1_1094/";
# function jumpPage() {
#   if (event.keyCode==37) location=preview_page;
#   if (event.keyCode==39) location=next_page;
#   if (event.keyCode==13) location=index_page;
# }
# document.onkeydown=jumpPage;
# </script>
# </head>
# <body id="wrapper">
# <script>login();</script>
# <div class="header">
# <div class="wrap">
# 	<div class="logo">
# 		<a href="/" title="±ÊÈ¤¸ó">±ÊÈ¤¸ó<em>www.biqukan.com</em></a>
# 	</div>
# 	<script>search();</script>
# </div>
# </div>
# 		<div class="nav">
# 		<ul>
# 				<li><a href="/">Ê×Ò³</a></li>
#                 <li><a href="/modules/article/bookcase.php">ÎÒµÄÊé¼Ü</a></li>
# 				<li><a href="/xuanhuanxiaoshuo/">Ðþ»ÃÐ¡Ëµ</a></li>
# 				<li><a href="/xiuzhenxiaoshuo/">ÐÞÕæÐ¡Ëµ</a></li>
# 				<li><a href="/dushixiaoshuo/">¶¼ÊÐÐ¡Ëµ</a></li>
# 				<li><a href="/chuanyuexiaoshuo/">´©Ô½Ð¡Ëµ</a></li>
# 				<li><a href="/wangyouxiaoshuo/">ÍøÓÎÐ¡Ëµ</a></li>
# 				<li><a href="/kehuanxiaoshuo/">¿Æ»ÃÐ¡Ëµ</a></li>
# 				<li><a href="/qitaxiaoshuo/">ÆäËûÐ¡Ëµ</a></li>
# 				<li><a href="/paihangbang/">ÅÅÐÐ°ñµ¥</a></li>
# 				<li><a href="/wanben/">Íê±¾Ð¡Ëµ</a></li>
# 		</ul>
# 		</div>
# <script>read1();</script>
# <div class="book reader">
# 	<div class="path"><div class="p"><a href="/">±ÊÈ¤¿´</a> &gt; <a href="/1_1094/">Ò»ÄîÓÀºã</a> &gt; µÚÒ»ÕÂ Ëû½Ð°×Ð¡´¿ <span class="oninfo"><script>textselect();</script></span>
# </div></div>
# 	<div class="content">
# 		<h1>µÚÒ»ÕÂ Ëû½Ð°×Ð¡´¿</h1>
# <div class="link"><span>±ÊÈ¤¸óÐ¡ËµÍÆ¼öÔÄ¶Á£º<a href="https://www.biqukan.com/1_1094/" target="_blank">Ò»ÄîÓÀºã</a>¡¢<a href="https://www.biqukan.com/0_178/" target="_blank">Ê¥Ðæ</a>¡¢<a href="https://www.biqukan.com/1_1682/" target="_blank">²»Ðà·²ÈË</a>¡¢<a href="https://www.biqukan.com/17_17957/" target="_blank">ÌìµÀÍ¼Êé¹Ý</a>¡¢<a href="https://www.biqukan.com/17_17939/" target="_blank">ÈË»Ê¼Í</a>¡¢<a href="https://www.biqukan.com/0_157/" target="_blank">Î×Éñ¼Í</a>¡¢<a href="https://www.biqukan.com/1_1452/" target="_blank">ÎäµÀ×ÚÊ¦</a>¡¢<a href="https://www.biqukan.com/16_16521/" target="_blank">¾øÊÀÕ½»ê</a>¡¢<a href="https://www.biqukan.com/18_18467/" target="_blank">³¬·²´«</a>¡¢
# <a href="https://www.biqukan.com/10_10567/" target="_blank">¸ÇÊÀµÛ×ð</a>¡¢<a href="https://www.biqukan.com/1_1421/" target="_blank">æýç«Ð°»Ê</a>¡¢<a href="https://www.biqukan.com/0_996/" target="_blank">ÏÀÐÐÌìÏÂ</a>¡¢<a href="https://www.biqukan.com/1_1021/" target="_blank">¿Ö²À¹ã²¥</a></span></div>
# <script>read2();</script>
# <br />&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ÎÒÃÇµÄÄ¿±ê£¬ÒÀ¾ÉÊÇ¡­¡­µã»÷°ñ£¬ÍÆ¼ö°ñ£¬µÚÒ»£¡xh:.181.241.250<br /><script>app2();</script><br /><br />¡¡¡¡(https://www.biqukan.com/1_1094/5403177.html)<br /><br /><script>chaptererror();</script><br />¡¡¡¡Çë¼Ç×¡±¾ÊéÊ×·¢ÓòÃû£ºwww.biqukan.com¡£±ÊÈ¤¸óÊÖ»ú°æÔÄ¶ÁÍøÖ·£ºn.biqukan.com</div>
# <script>read3();</script>
# 		<div class="page_chapter">
# 			<ul>
# 				<li><a href="/1_1094/5386268.html">ÉÏÒ»ÕÂ</a></li>
# 				<li><a href="/1_1094/">·µ»ØÄ¿Â¼</a></li>
# 				<li><a href="/1_1094/5428081.html">ÏÂÒ»ÕÂ</a></li>
# 				<li><a rel="nofollow" href="javascript:addBookMark('1094','5403177','Ò»ÄîÓÀºã','µÚÒ»ÕÂ Ëû½Ð°×Ð¡´¿');">¼ÓÈëÊéÇ©</a>
# </li>
# 			</ul>
# 		</div>
# <script>read4();</script>
# 	</div>
# </div>
#
# <script>lastread.set('1094','5403177','Ò»ÄîÓÀºã','µÚÒ»ÕÂ Ëû½Ð°×Ð¡´¿','¶ú¸ù','ÐÞÕæÐ¡Ëµ');</script>
#
# <div class="footer">
# 	<div class="link"><span>Ò»ÄîÓÀºãÎÞµ¯´°Ïà¹ØÍÆ¼ö£º
# <a href="/1_1093/">Éú¶ø²»·²ÁÖ±±</a>¡¢<a href="/1_1092/">Áù³¯Ê±¿ÕÉñÏÉ´«</a>¡¢<a href="/1_1091/">³Â¸èÂíÏþéª</a>¡¢<a href="/1_1090/">¿¹ÈÕÖ®ÍõÅÆÌØ¹¤</a>¡¢<a href="/1_1089/">ÑÖÅÐ</a>¡¢<a href="/1_1088/">ÖÁÇ¿Õ½Éñ³ÂºÆÌÆÐãÐÄ</a>¡¢<a href="/1_1087/">¶«¾©ÉðÊ¿ÎïÓï</a>¡¢<a href="/1_1086/">¾øÊÀ´óÉÙ³Â¸èÂíÏþéª</a>¡¢<a href="/1_1085/">²»Á¼Ö®Ë­ÓëÕù·æ</a>¡¢<a href="/1_1084/">Ä©ÊÀÖ®ÕýÄÜÁ¿ÏµÍ³</a>¡¢</span></div>
# <hr>
# µÚÒ»ÕÂ Ëû½Ð°×Ð¡´¿_Ò»ÄîÓÀºã×îÐÂÕÂ½Ú_ÐÞÕæÐ¡Ëµ<br/>
# 	<script>footer();tj();readtc();</script>
# </div>
# </body>
# </html>
